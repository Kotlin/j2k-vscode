# %% [markdown]
# # Chapter 3: Assigning Roles (Role Prompting)
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# Import python's built-in regular expression library
import re
import anthropic

# Retrieve the API_KEY & MODEL_NAME variables from the IPython store
# %store -r API_KEY
# %store -r MODEL_NAME

client = anthropic.Anthropic(api_key=API_KEY)

def get_completion(prompt: str, system_prompt=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# ---
#
# ## Lesson
#
# Continuing on the theme of Claude having no context aside from what you say, it's sometimes important to **prompt Claude to inhabit a specific role (including all necessary context)**. This is also known as role prompting. The more detail to the role context, the better.
#
# **Priming Claude with a role can improve Claude's performance** in a variety of fields, from writing to coding to summarizing. It's like how humans can sometimes be helped when told to "think like a ______". Role prompting can also change the style, tone, and manner of Claude's response.
#
# **Note:** Role prompting can happen either in the system prompt or as part of the User message turn.

# %% [markdown]
# ### Examples
#
# In the example below, we see that without role prompting, Claude provides a **straightforward and non-stylized answer** when asked to give a single sentence perspective on skateboarding.
#
# However, when we prime Claude to inhabit the role of a cat, Claude's perspective changes, and thus **Claude's response tone, style, content adapts to the new role**.
#
# **Note:** A bonus technique you can use is to **provide Claude context on its intended audience**. Below, we could have tweaked the prompt to also tell Claude whom it should be speaking to. "You are a cat" produces quite a different response than "you are a cat talking to a crowd of skateboarders.
#
# Here is the prompt without role prompting in the system prompt:

# %%
# Prompt
PROMPT = "In one sentence, what do you think about skateboarding?"

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# It's a thrilling blend of physical skill, daring stunts, and vibrant culture that embodies freedom and creativity on wheels.

# %% [markdown]
# Here is the same user question, except with role prompting.

# %%
# System prompt
SYSTEM_PROMPT = "You are a cat."

# Prompt
PROMPT = "In one sentence, what do you think about skateboarding?"

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))
# Out:
# It's like watching a little mouse try to balance on its hind legs while running in place!

# %% [markdown]
# You can use role prompting as a way to get Claude to emulate certain styles in writing, speak in a certain voice, or guide the complexity of its answers. **Role prompting can also make Claude better at performing math or logic tasks.**
#
# For example, in the example below, there is a definitive correct answer, which is yes. However, Claude gets it wrong and thinks it lacks information, which it doesn't:

# %%
# Prompt
PROMPT = "Jack is looking at Anne. Anne is looking at George. Jack is married, George is not, and we don’t know if Anne is married. Is a married person looking at an unmarried person?"

# Print Claude's response
print(get_completion(PROMPT, "give the response as yes/no"))
# Out:
# <think>
# First, the question is: "Is a married person looking at an unmarried person?" I need to figure this out based on the given information.
#
# Given:
#
# - Jack is looking at Anne.
#
# - Anne is looking at George.
#
# - Jack is married.
#
# - George is not married (unmarried).
#
# - We don't know about Anne's marital status.
#
# I need to determine if there is a married person who is looking at an unmarried person. There might be multiple people involved, so I should consider all possibilities for Anne.
#
# Let me denote the statuses:
#
# - Jack: Married
#
# - George: Unmarried (since it says "George is not" and we assume that means unmarried)
#
# Anne's status is unknown; she could be married or unmarried.
#
# Now, who is looking at whom?
#
# 1. Jack is looking at Anne.
#
# 2. Anne is looking at George.
#
# The question is about a married person looking at an unmarried person. So, I need to see if in any case this happens.
#
# Consider the two cases for Anne:
#
# Case 1: Anne is married.
#
# If Anne is married, then:
#
# - Jack (married) is looking at Anne (married). But we're interested in whether a married person looks at an unmarried one here. Since both are married, it doesn't satisfy "looking at an unmarried person."
#
# Now, Anne is looking at George. Anne is married, George is unmarried.
#
# So, Anne (married) is looking at George (unmarried), which means there is a married person (Anne) looking at an unmarried person (George).
#
# But the question might be interpreted as whether someone who is married is currently looking at someone who is unmarried. In this case, when Anne looks at George, she is married and he is unmarried.
#
# Also, Jack is looking at Anne, but if Anne is married, then both are married, so that doesn't count for a married person looking at an unmarried one.
#
# But the question says "is a married person looking at an unmarried person?" It might be asking about existence in this scenario. Since Anne is looking at George and she's married while he's unmarried, yes, there is such a case if Anne is married.
#
# Case 2: Anne is unmarried.
#
# If Anne is unmarried:
#
# - Jack (married) is looking at Anne (unmarried). So here, Jack (married) is looking at an unmarried person (Anne).
#
# Also, Anne (unmarried) is looking at George (unmarried), so both are unmarried. That doesn't involve a married person looking at unmarried.
#
# But in this case, when Anne is unmarried and looks at George, it's unmarried to unmarried, which isn't relevant for the question.
#
# Now, back to Case 1: If Anne is married, then Anne is looking at George (unmarried), so there is a married person (Anne) looking at an unmarried person (George).
#
# In Case 2: If Anne is unmarried, then Jack (married) is looking at Anne (unmarried), so again, there is a married person (Jack) looking at an unmarried person (Anne).
#
# So in both cases, regardless of Anne's status, there is always a situation where a married person is looking at an unmarried person.
#
# Let me confirm:
#
# - If Anne is married: Then Anne looks at George who is unmarried. So Anne (married) -> George (unmarried)
#
# - If Anne is unmarried: Then Jack looks at Anne who is unmarried. So Jack (married) -> Anne (unmarried)
#
# In the first case, when Anne is married, she is looking at George, so that's one instance.
#
# In the second case, when Anne is unmarried, Jack is looking at her, so another instance.
#
# But in both scenarios, there exists a married person who is looking at an unmarried person.
#
# The question might be tricky because it says "we don’t know if Anne is married." But from above, it seems that no matter what, the condition holds.
#
# Perhaps I need to think about whether this is necessarily true or not.
#
# Let me define:
#
# M: Married
#
# U: Unmarried
#
# J: Jack (M)
#
# A: Anne (?)
#
# G: George (U)
#
# Now, looking relations:
#
# - J looks at A
#
# - A looks at G
#
# We want to know if there exists a married person who is looking at an unmarried person.
#
# In other words, does there exist X such that X is M and X is looking at Y where Y is U.
#
# X could be Jack or Anne, depending on the case.
#
# If Anne is M, then X = Anne (M) looks at G (U)
#
# If Anne is U, then X = Jack (M) looks at A (U)
#
# So in both possibilities for Anne, there is a married person looking at an unmarried person.
#
# Therefore, it must be true that a married person is looking at an unmarried person.
#
# But let's make sure about the "looking" part. Is it possible that someone isn't directly involved? No, because we're given two specific lookings: Jack looks at Anne, and Anne looks at George.
#
# Also, are there any other people or assumptions? The question doesn't mention anyone else, so I think only these three are relevant.
#
# Perhaps the question is about whether a married person exists who is looking at an unmarried person in this setup.
#
# But from above, it seems consistent.
#
# Another way to look at it: Maybe we need to consider if Anne herself is part of the "looking" for the condition.
#
# In Case 1 (Anne M): Anne looks at George U, so yes.
#
# In Case 2 (Anne U): Jack looks at Anne U, so yes.
#
# But what about George? He is unmarried and being looked at by Anne. But we don't know if Anne is married or not when she's looking at him; it depends on the case.
#
# The condition doesn't require that the unmarried person is being looked at only by a married one or anything like that. It just asks if there exists a situation where a married person looks at an unmarried person.
#
# In this scenario, since we have two lookings:
#
# 1. Jack looking at Anne
#
# 2. Anne looking at George
#
# And in both cases (Anne M or U), the first looking involves either married to unknown or unknown to unmarried, but specifically for the existence of a married-to-unmarried looking pair.
#
# When Anne is M: The looking from J to A doesn't satisfy because both are M. But the looking from A to G does satisfy because A is M and G is U.
#
# Similarly, when Anne is U: Looking from J to A satisfies because J is M and A is U (since Anne is unmarried). And looking from A to G also involves a married person? No, in this case A is U, so not relevant for the condition.
#
# But since there's at least one instance where it holds—either through Jack or through Anne depending on her status—it must be true that such a thing exists.
#
# Perhaps the question is poorly worded. Let me read it again: "Is a married person looking at an unmarried person?"
#
# It might be ambiguous, but I think in context, it means to determine if there is a married individual who has their gaze directed towards an unmarried individual.
#
# And from above, yes.
#
# But let's see why this might be confusing. Sometimes these logic puzzles have tricks with the unknown status.
#
# Another thought: Maybe "looking at" implies that we're considering only direct lookings, and perhaps Anne could be looking at George while Jack is not involved in that direction or something, but no, the question doesn't say that.
#
# Perhaps it's about whether a married person exists who is looking at an unmarried person, meaning someone must be doing this action.
#
# But again, from above, when Anne looks at George, if she's married, then yes; if not, Jack looks at her and since she's unmarried, he does it.
#
# So in all cases, there is always a married person looking at an unmarried person.
#
# Unless... what if no one is looking? But the question states that Jack is looking at Anne and Anne is looking at George, so lookings are happening.
#
# Perhaps we need to consider the possibility that Anne might not be considered "looking" for some reason, but I think she is.
#
# Maybe the marital status affects who can see whom or something, but no, it's just about existence of such a pair in the given relations.
#
# I think I'm overcomplicating. Let me state it clearly:
#
# There are two lookings to consider:
#
# - Looking 1: Jack (M) looks at Anne (?)
#
# - Looking 2: Anne (?) looks at George (U)
#
# Now, for there to be no married person looking at an unmarried person, we need that in both lookings, the one doing the looking is not married or they are looking at someone who is married.
#
# But:
#
# In Looking 1, Jack is always married and he's looking at Anne. If Anne is unmarried, then this satisfies (M looks at U). If Anne is married, it doesn't satisfy for this looking.
#
# In Looking 2, Anne is looking at George who is always unmarried. So if Anne is married, she looks at U; if Anne is unmarried, she looks at U but since she's not married, it doesn't count as a M-U looking pair from her side.
#
# The condition "a married person looking at an unmarried person" can be satisfied by:
#
# - Jack (M) looking at Anne: this requires that Anne is U
#
# - Or Anne (if M) looking at George (U)
#
# If Anne is U, then the first possibility holds because J looks at A and both are not necessarily same status—J is M, A is U.
#
# If Anne is U:
#
# Then Looking 1: J(M) looks at A(U), so married person (Jack)

# %% [markdown]
# Now, what if we **prime Claude to act as a logic bot**? How will that change Claude's answer?
#
# It turns out that with this new role assignment, Claude gets it right. (Although notably not for all the right reasons)

# %%
# System prompt
SYSTEM_PROMPT = "You are a logic bot designed to answer complex logic problems."

# Prompt
PROMPT = "Jack is looking at Anne. Anne is looking at George. Jack is married, George is not, and we don’t know if Anne is married. Is a married person looking at an unmarried person?"

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))
# Out:
# <think>
# First, the question is: "Is a married person looking at an unmarried person?"
#
# We have three people: Jack, Anne, and George.
#
# Given:
#
# - Jack is married.
#
# - George is not married (unmarried).
#
# - We don't know about Anne's marital status.
#
# The relationships are:
#
# - Jack is looking at Anne.
#
# - Anne is looking at George.
#
# I need to determine if there is a married person who is currently looking at an unmarried person.
#
# Since we're dealing with "looking at" in the present, I should consider the direct lines of sight or attention based on the given statements.
#
# Let me denote:
#
# - M: Married
#
# - U: Unmarried (not married)
#
# So, Jack = M
#
# Anne = ? (unknown)
#
# George = U
#
# Now, the looking relationships:
#
# - Jack is looking at Anne. So, if Anne is unmarried, then a married person (Jack) is looking at an unmarried person (Anne). But we don't know if Anne is married or not.
#
# - Anne is looking at George. George is unmarried, so if Anne is married, then a married person (Anne) is looking at an unmarried person (George).
#
# The question doesn't specify who else might be involved or any other conditions. It's just about these three people and their current looks.
#
# I need to consider the possibilities for Anne's marital status.
#
# Case 1: If Anne is married.
#
# Then:
#
# - Jack (M) is looking at Anne (M), so a married person is looking at another married person, not unmarried.
#
# - Anne (M) is looking at George (U), so here, a married person (Anne) is looking at an unmarried person (George).
#
# So in this case, yes, there is a married person looking at an unmarried person: specifically, Anne is doing that.
#
# Case 2: If Anne is not married.
#
# Then:
#
# - Jack (M) is looking at Anne (U), so married person looking at unmarried person. Yes.
#
# - Anne (U) is looking at George (U), but since Anne is unmarried and George is unmarried, this doesn't directly answer the question about a married person looking at unmarried; it's an unmarried person looking at another unmarried person.
#
# But in Case 2, when Anne is unmarried, Jack is still looking at her, so that satisfies the condition: married person (Jack) looking at unmarried person (Anne).
#
# Now, what if Anne is unknown? The question says "we don’t know if Anne is married," but we need to find out based on the information.
#
# The answer should be yes in both cases where Anne's status is defined or not?
#
# Let me think carefully.
#
# If Anne is married:
#
# - Jack looks at Anne (both M, so no)
#
# - But Anne looks at George (M and U, so yes)
#
# So there exists a situation: Anne looking at George.
#
# If Anne is unmarried:
#
# - Jack looks at Anne (M and U, so yes)
#
# - Anne looks at George (U and U, not relevant for the question)
#
# Again, in this case, Jack looking at Anne satisfies it.
#
# Now, what if Anne's status doesn't affect anything? But in both scenarios above, there is always a married person looking at an unmarried person or something similar.
#
# Let me list all possibilities:
#
# Anne can be either married (M) or unmarried (U).
#
# First subcase: Anne = M
#
# - Jack looks at Anne: both M → not the condition we're seeking for this part.
#
# We're seeking if there is any instance where a married person is looking at an unmarried person.
#
# In this case, when Anne looks at George, it's M looking at U.
#
# Second subcase: Anne = U
#
# - Jack looks at Anne: M looking at U → yes.
#
# Now, in the first subcase (Anne=M), we have Anne looking at George which is M to U.
#
# But the question is about "a married person looking at an unmarried person" – it doesn't specify that it has to be directly or anything else. It just asks if such a thing exists given the current looks.
#
# Also, note that Jack and Anne are both looking, but we're only concerned with who is looking from whom's perspective? No, the question is: "Is a married person looking at an unmarried person?"
#
# It means: Is there someone who is married and they are currently looking at someone who is unmarried?
#
# From the given:
#
# - Jack (M) is looking at Anne. So if Anne is U, then yes.
#
# But we don't know Anne's status.
#
# Similarly, Anne is looking at George (U). If Anne is M, then when she looks at George, it satisfies.
#
# So in both cases where Anne is defined, there is a possibility:
#
# - If Anne is married, then Anne (M) is looking at George (U)
#
# - If Anne is unmarried, then Jack (M) is looking at Anne (U)
#
# But what if Anne's status is unknown? Does that mean we can't determine?
#
# The question doesn't say to assume anything about Anne; it just says we don't know.
#
# However, in logic problems like this, often the answer depends on whether such a situation must be true or could be false based on the information.
#
# Let me read the question again: "Is a married person looking at an unmarried person?"
#
# And the given facts are fixed except for Anne's status.
#
# Anne's status is not specified, so it could be either way.
#
# But in both scenarios:
#
# - If Anne is M, then there is a married person (Anne) looking at unmarried George.
#
# - If Anne is U, then there is married Jack looking at unmarried Anne.
#
# In the case where Anne is U, we have one instance: Jack looks at Anne.
#
# If Anne is M, we have another instance: Anne looks at George.
#
# But when Anne is M, does Jack look at someone else? No, the statement only says Jack is looking at Anne, so in that context, it's about Anne and George.
#
# Similarly for Anne being U.
#
# Now, there might be a trick here. The question doesn't specify if "looking" implies direct eye contact or something; I think we should take it as given that these looks are happening between them.
#
# Another thing: is the look mutual? No, Jack is looking at Anne, and Anne is looking at George, but they might not be looking at each other directly. For example, Anne could be looking away from Jack towards George or something, but I think for this problem, we assume that "looking" means their attention is directed to that person.
#
# But the key point is: regardless of Anne's status, there is always a married person who might be looking at an unmarried person.
#
# Specifically:
#
# - If Anne is married, then Anne (married) is looking at George (unmarried).
#
# - If Anne is unmarried, then Jack (married) is looking at Anne (unmarried).
#
# In both cases, the condition holds: there exists a married person looking at an unmarried person.
#
# But let's confirm if this is necessarily true or not.
#
# Suppose Anne is married. Then, as above, Anne looks at George who is unmarried.
#
# Now, does Jack look at anyone else? The statement doesn't say he only looks at Anne; it just says he is looking at Anne. But for the purpose of "is a married person looking at an unmarried person?", we need to see if in this setup, such a thing occurs.
#
# Similarly, when Anne is unmarried, Jack looks at her who is unmarried.
#
# But what about George? He might be looking or not, but it's not specified.
#
# The question doesn't mention anyone else, so I think we're only concerned with the people mentioned: Jack, Anne, and George.
#
# Now, let's consider if there is any case where no married person is looking at an unmarried person.
#
# For that to happen:
#
# - If Anne is married, then when Anne looks at George (unmarried), it would be a problem unless... but in this case, Anne is married and she is looking at George who is unmarried, so the condition holds.
#
# If Anne is married, and we want no instance of M looking at U, that means:
#
# - Jack should not be looking at an unmarried person. But Jack is looking at Anne, who is married (in this subcase), so he is looking at a married person, which doesn't violate anything for the "no" case.
#
# But in this setup, when Anne looks at George, she is M looking at U, so there is one instance.
#
# To have no M looking at U:
#
# - Jack must not be looking at an unmarried person. Since he is looking at Anne, Anne must be married (so that M to M).
#
# - Also, Anne must not be looking at an unmarried person when she looks at George. But George is unmarried, so if Anne is looking at him, and we want no M to U, then Anne cannot be married in this case.
#
# Let's clarify:
#
# For there to be NO situation where a married person is looking at an unmarried person:
#
# - Jack must not be looking at an unmarried person: since he is looking at Anne, Anne must be married (so that it's M to M).
#
# - Anne must not be looking at an unmarried person when she looks at George. But George is unmarried, so if Anne were looking at him and Anne was unmarried, then U to U, which doesn't count as M to U. If Anne is married, then M to U with George.
#
# But for the "no" case:
#
# - To avoid Jack being M to U: Anne must be M (since he's looking at her).
#
# - Then, when Anne looks at George, if Anne is M and George is U, that would be a M to U situation, which we don't want. So to

# %% [markdown]
# **Note:** What you'll learn throughout this course is that there are **many prompt engineering techniques you can use to derive similar results**. Which techniques you use is up to you and your preference! We encourage you to **experiment to find your own prompt engineering style**.
#
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 3.1 - Math Correction](#exercise-31---math-correction)

# %% [markdown]
# ### Exercise 3.1 - Math Correction
# In some instances, **Claude may struggle with mathematics**, even simple mathematics. Below, Claude incorrectly assesses the math problem as correctly solved, even though there's an obvious arithmetic mistake in the second step. Note that Claude actually catches the mistake when going through step-by-step, but doesn't jump to the conclusion that the overall solution is wrong.
#
# Modify the `PROMPT` and / or the `SYSTEM_PROMPT` to make Claude grade the solution as `incorrectly` solved, rather than correctly solved.

# %%
# System prompt - if you don't want to use a system prompt, you can leave this variable set to an empty string
SYSTEM_PROMPT = ""

# Prompt
PROMPT = """Is this equation solved correctly below?

2x - 3 = 9
2x = 6
x = 3"""

# Get Claude's response
response = get_completion(PROMPT, SYSTEM_PROMPT)

# Function to grade exercise correctness
def grade_exercise(text):
    if "incorrect" in text or "not correct" in text.lower():
        return True
    else:
        return False

# Print Claude's response and the corresponding grade
print(response)
print("\n--------------------------- GRADING ---------------------------")
print("This exercise has been correctly solved:", grade_exercise(response))

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_3_1_hint; print(exercise_3_1_hint)

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = "In one sentence, what do you think about skateboarding?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# System prompt
SYSTEM_PROMPT = "You are a cat."

# Prompt
PROMPT = "In one sentence, what do you think about skateboarding?"

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))

# %%
# Prompt
PROMPT = "Jack is looking at Anne. Anne is looking at George. Jack is married, George is not, and we don’t know if Anne is married. Is a married person looking at an unmarried person?"

# Print Claude's response
print(get_completion(PROMPT))

# %%
# System prompt
SYSTEM_PROMPT = "You are a logic bot designed to answer complex logic problems."

# Prompt
PROMPT = "Jack is looking at Anne. Anne is looking at George. Jack is married, George is not, and we don’t know if Anne is married. Is a married person looking at an unmarried person?"

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))
